# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolinaQP/2023-2_Programacion/blob/main/Trabajo_FinalP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabajo final

# %% [markdown]
# ## Descarga de librerías

# %%
# !pip install openpyxl
# !pip install tqdm
# !pip install reportlab
# !pip install python-docx
# !pip install python-pptx
# !pip install XlsxWriter
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install Pillow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 16.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importar librerías

# %%
import os
from openpyxl import Workbook
from docx import Document
import random as rnd
import pandas as pd
from PIL import Image, ImageDraw, ImageFont
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
import time
import datetime
import warnings
warnings.filterwarnings('ignore')
import logging
import tqdm
from google.colab import files
import shutil

# %% [markdown]
# ## Generar los archivos

# %%
inicio = time.time()
print('Ingresar la cantidad de archivos a procesar, ingresar solo numeros enteros.')
print('Si ingresa el numero 10, por ejemplo, se crearan 10 archivos de cada uno.')
print('Generando un total de 100 archivos, A continuacion ingresar el numero.')
archivos = int(input('Ingresar la cantidad: '))
hoy = datetime.date.today().strftime('%Y%m%d')
nombre_archivo_log = f"log_{hoy}.log"
logging.basicConfig(filename=nombre_archivo_log, level=logging.INFO,
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logging.info("Iniciando el proceso, por CastilloEnterprises (^人^)(^人^)(^人^)")


#Creamos el directorio (carpeta) en donde se crearan los archivos
DirectorioActual = os.getcwd()
print(f'El directorio actual de trabajo es: \n\t--> {DirectorioActual}, \nEsta carpeta contendrá los archivos del trabajo final')
CarpetaNueva = "CarpetaArchivosTrabajoFinal"
os.makedirs(CarpetaNueva, exist_ok=True)
logging.info("Se crea el directorio {}".format(CarpetaNueva))
print(f"'{CarpetaNueva}' La carpeeta ha sido creada.")
# Nombre de la carpeta donde se crearán los archivos
carpeta = os.path.join(DirectorioActual, "CarpetaArchivosTrabajoFinal")
logging.info("La ruta de trabajo será {}".format(carpeta))
RutaNombres = r'https://raw.githubusercontent.com/juliancastillo-udea/Curso_AlgoritmosProgramacion/main/TrabajoFinal/NombresArgentina.csv'
logging.info("Cargando CSV con nombres")
dfNombres = pd.read_csv(RutaNombres, encoding='ISO-8859-1')
Nombres = dfNombres['name'].tolist()
logging.info("Reemplazando nombres y detalles del documento")
for i in tqdm.trange(len(Nombres)):
    if ' ' in Nombres[i]:
        Nombres[i]=Nombres[i].replace(' ', '_')
logging.info("Creacion de archivos")
for i in tqdm.trange(int(archivos), miniters=int(1), ascii=True,desc="Creando Archivos", dynamic_ncols=True):
    # Crear un archivo de Excel usando openpyxl--------------------------------
    logging.info(f"Creacion de archivos-->Excel {i+1}")
    wb = Workbook()
    ws = wb.active
    ws['A1'] = 'Hola soy un numero aleatorio'
    ws['A2'] = rnd.random()
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    excel_filename = os.path.join(carpeta, tempNombre+'.xlsx')
    wb.save(excel_filename)

    # Crear un archivo de Word usando python-docx------------------------------
    logging.info(f"Creacion de archivos-->Word {i+1}")
    doc = Document()
    doc.add_paragraph(f"¡Hola! Este es un archivo de Word creado desde Python. \n Soy un numero aleatorio {rnd.random()}")
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    word_filename = os.path.join(carpeta, tempNombre+'.docx')
    doc.save(word_filename)

    # Crear un archivo de texto (txt)------------------------------------------
    logging.info(f"Creacion de archivos-->Texto {i+1}")
    texto = f"¡Hola! Este es un archivo de Word creado desde Python. \n Soy un numero aleatorio {rnd.random()}"
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    txt_filename = os.path.join(carpeta, tempNombre+'.txt')
    with open(txt_filename, 'w') as txt_file:
        txt_file.write(texto)

    # Crear un archivo CSV-----------------------------------------------------
    logging.info(f"Creacion de archivos-->CSV {i+1}")
    csv_data = f"Nombre,Edad\n{rnd.choice(Nombres)},{rnd.uniform(18,60)}\n"
    csv_data += f"{rnd.choice(Nombres)},{rnd.uniform(18,60)}\n"
    csv_data += f"{rnd.choice(Nombres)},{rnd.uniform(18,60)}\n"
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    csv_filename = os.path.join(carpeta, tempNombre+'.csv')
    with open(csv_filename, 'w') as csv_file:
        csv_file.write(csv_data)

    # Crear un archivo JSON----------------------------------------------------
    logging.info(f"Creacion de archivos-->JSON {i+1}")
    import json
    json_data = {"nombre": rnd.choice(Nombres), "edad": rnd.uniform(18,60)}
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    json_filename = os.path.join(carpeta, tempNombre+'.json')
    with open(json_filename, 'w') as json_file:
        json.dump(json_data, json_file, indent=4)

    # Crear un archivo XML-----------------------------------------------------
    logging.info(f"Creacion de archivos-->XML {i+1}")
    xml_data = f"""<?xml version="1.0" encoding="UTF-8"?>
    <datos>
        <persona>
            <nombre>{rnd.choice(Nombres)}</nombre>
            <edad>{rnd.uniform(18,60)}</edad>
        </persona>
        <persona>
            <nombre>{rnd.choice(Nombres)}</nombre>
            <edad>{rnd.uniform(18,60)}</edad>
        </persona>
    </datos>
    """
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    xml_filename = os.path.join(carpeta, tempNombre+'.xml')
    with open(xml_filename, 'w') as xml_file:
        xml_file.write(xml_data)

    # Crear un archivo de PowerPoint-------------------------------------------
    logging.info(f"Creacion de archivos-->PowerPoint {i+1}")
    from pptx import Presentation
    ppt = Presentation()
    slide = ppt.slides.add_slide(ppt.slide_layouts[0])
    slide.shapes.title.text = f"Presentación creada desde Python,\n Soy un numero aleatorio {rnd.random()}"
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    ppt_filename = os.path.join(carpeta, tempNombre+'.pptx')
    ppt.save(ppt_filename)

    # Crear un archivo HTML----------------------------------------------------
    logging.info(f"Creacion de archivos-->HTML {i+1}")
    html_data = """<!DOCTYPE html>
    <html>
    <head>
        <title>Página HTML creada desde Python</title>
    </head>
    <body>
        <h1>Hola desde Python</h1>
        <h1>Hola soy un numero aleatorio {}</h1>
    </body>
    </html>
    """.format(rnd.random())
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    html_filename = os.path.join(carpeta, tempNombre+'.html')
    with open(html_filename, 'w') as html_file:
        html_file.write(html_data)

    #Crear una imagen vacía----------------------------------------------------
    logging.info(f"Creacion de archivos-->Imagen PNG {i+1}")
    ancho = 400
    alto = 400
    imagen_vacia = Image.new('RGB', (ancho, alto), 'white')
    texto = f"Hola soy un numero aleatorio\n {rnd.random()}"
    #fuente = ImageFont.truetype("arial.ttf", 20)
    dibujar = ImageDraw.Draw(imagen_vacia)
    bbox = dibujar.textbbox((0,0), texto)
    ancho_texto = bbox[2] - bbox[0]
    alto_texto = bbox[3] - bbox[1]
    x = (ancho - ancho_texto) / 2
    y = (alto - alto_texto) / 2
    dibujar.text((x, y), texto, fill="black")
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    imagen = os.path.join(carpeta, tempNombre+'.png')
    imagen_vacia.save(imagen)

    #Archivo PDF---------------------------------------------------------------
    logging.info(f"Creacion de archivos-->PDF {i+1}")
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    pdfarchivo = os.path.join(carpeta, tempNombre+'.pdf')
    c = canvas.Canvas(pdfarchivo, pagesize=letter)
    width, height = letter
    texto = f"Hola soy un archivo PDF con un numero aleatorio \n {rnd.random()}"
    c.drawString(width/4 - 15, height/3, texto)  # Ajusta la posición según lo que necesites
    c.save()
logging.info("Proceso Terminado......")
logging.info("Gracias por usar Castillo Enterprises")
logging.shutdown()

fin = time.time()
tiempoejecucion = fin - inicio
minutos = int(tiempoejecucion // 60)
segundos = tiempoejecucion % 60
print(f"El script tomó {minutos} minutos y {segundos:.2f} segundos para ejecutarse.")
# Out:
# Ingresar la cantidad de archivos a procesar, ingresar solo numeros enteros.
# Si ingresa el numero 10, por ejemplo, se crearan 10 archivos de cada uno.
# Generando un total de 100 archivos, A continuacion ingresar el numero.
# Ingresar la cantidad: 1000
# El directorio actual de trabajo es:
# 	--> /content,
# Esta carpeta contendrá los archivos del trabajo final
# 'CarpetaArchivosTrabajoFinal' La carpeeta ha sido creada.
# ...
# Creando Archivos: 100%|##########| 1000/1000 [01:26<00:00, 11.53it/s]
# El script tomó 1 minutos y 43.52 segundos para ejecutarse.

# %%
# !zip -r /content/CarpetaArchivosTrabajoFinal.zip /content/CarpetaArchivosTrabajoFinal
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   adding: content/CarpetaArchivosTrabajoFinal/BRINDUSA.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOHN_TREVOR.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOAO_MIGUEL.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/ORBELINDA.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/HECTOR_DAMIAN.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUNIOR_MANUEL.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/VIANEY.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/PAULA_ROSARIO.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/RONALD_FREDERICK.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/VIRGINIA_PATRICIA.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/KHATRI.png (deflated 61%)
# ...

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ###Clasificación de las extensiones

# %%
dir_path = r'/content/CarpetaArchivosTrabajoFinal'
res = []
for path in os.listdir(dir_path):
    if os.path.isfile(os.path.join(dir_path, path)):
        res.append(path)
nuevo_vector = []
for i in res:
    nuevo_vector.append(i.split("."))

Excel = []
Word = []
TXT = []
CSV = []
JSON = []
XML = []
Power_Point = []
HTML = []
PNG = []
PDF = []

for j in nuevo_vector:
    if j[1] == 'csv':
        CSV.append(j)

    elif j[1] == 'docx':
        Word.append(j)

    elif j[1] == 'pdf':
        PDF.append(j)

    elif j[1] == 'xml':
        XML.append(j)

    elif j[1] == 'xlsx':
        Excel.append(j)

    elif j[1] == 'json':
        JSON.append(j)

    elif j[1] == 'pptx':
        Power_Point.append(j)

    elif j[1] == 'html':
        HTML.append(j)

    elif j[1] == 'txt':
        TXT.append(j)

    elif j[1] == 'png':
        PNG.append(j)

    else:
        print("Archivo no identificado")

# %% [markdown]
# ##Creación de las carpetas según extensión y enumeración de las mismas

# %%
r_excel = '/content/Excel'

if not os.path.exists(r_excel):
    os.makedirs(r_excel)

for i, archivo_info in enumerate(Excel, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_excel, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#__________________________________________________________________________________________

r_Word = '/content/Word'

if not os.path.exists(r_Word):
    os.makedirs(r_Word)

for i, archivo_info in enumerate(Word, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_Word, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#__________________________________________________________________________________________

r_TXT = '/content/TXT'

if not os.path.exists(r_TXT):
    os.makedirs(r_TXT)

for i, archivo_info in enumerate(TXT, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_TXT, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#__________________________________________________________________________________________

r_CSV = '/content/CSV'

if not os.path.exists(r_CSV):
    os.makedirs(r_CSV)

for i, archivo_info in enumerate(CSV, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_CSV, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#__________________________________________________________________________________________

r_JSON = '/content/JSON'

if not os.path.exists(r_JSON):
    os.makedirs(r_JSON)

for i, archivo_info in enumerate(JSON, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_JSON, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#__________________________________________________________________________________________


r_XML = '/content/XML'

if not os.path.exists(r_XML):
    os.makedirs(r_XML)

for i, archivo_info in enumerate(XML, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_XML, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#__________________________________________________________________________________________

r_Power_Point = '/content/Power_Point'

if not os.path.exists(r_Power_Point):
    os.makedirs(r_Power_Point)

for i, archivo_info in enumerate(Power_Point, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_Power_Point, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#_________________________________________________________________________________________


r_HTML = '/content/HTML'

if not os.path.exists(r_HTML):
    os.makedirs(r_HTML)

for i, archivo_info in enumerate(HTML, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_HTML, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#_________________________________________________________________________________________

r_PNG = '/content/PNG'

if not os.path.exists(r_PNG):
    os.makedirs(r_PNG)

for i, archivo_info in enumerate(PNG, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_PNG, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

#_________________________________________________________________________________________

r_PDF = '/content/PDF'

if not os.path.exists(r_PDF):
    os.makedirs(r_PDF)

for i, archivo_info in enumerate(PDF, start=1):
    nombre_archivo, extension = archivo_info
    ruta_origen = f'/content/CarpetaArchivosTrabajoFinal/{nombre_archivo}.{extension}'
    ruta_destino = os.path.join(r_PDF, f'{i:03d}-{nombre_archivo}.{extension}')

    shutil.move(ruta_origen, ruta_destino)

# %% [markdown]
# ##Pandas Dataframe con información organizada y detallada

# %%
# !pip install tabulate

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('CSV\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/CSV'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/CSV'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# CSV
#
# +--------------------------------+--------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+------------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |    Nombre Archivo Anterior     |     Nombre Archivo Actual      | Ruta Anterior |  Nueva Ruta  | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |   Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +--------------------------------+--------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+------------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('Excel\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/Excel'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/Excel'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# Excel
#
# +---------------------------------+---------------------------------+----------------+----------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |     Nombre Archivo Anterior     |      Nombre Archivo Actual      | Ruta Anterior  |   Nueva Ruta   | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |  Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +---------------------------------+---------------------------------+----------------+----------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('HTML\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/HTML'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/HTML'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# HTML
#
# +--------------------------------+--------------------------------+---------------+---------------+-----------------+---------------+----------------+--------------------+------------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |    Nombre Archivo Anterior     |     Nombre Archivo Actual      | Ruta Anterior |  Nueva Ruta   | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |   Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +--------------------------------+--------------------------------+---------------+---------------+-----------------+---------------+----------------+--------------------+------------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('JSON\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/JSON'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/JSON'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# JSON
#
# +-----------------------------------+-----------------------------------+---------------+---------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |      Nombre Archivo Anterior      |       Nombre Archivo Actual       | Ruta Anterior |  Nueva Ruta   | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |  Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +-----------------------------------+-----------------------------------+---------------+---------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('PDF\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/PDF'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/PDF'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# PDF
#
# +--------------------------------+--------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |    Nombre Archivo Anterior     |     Nombre Archivo Actual      | Ruta Anterior |  Nueva Ruta  | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |  Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +--------------------------------+--------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('PNG\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/PNG'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/PNG'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# PNG
#
# +--------------------------------+--------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |    Nombre Archivo Anterior     |     Nombre Archivo Actual      | Ruta Anterior |  Nueva Ruta  | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |  Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +--------------------------------+--------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('Power_Point\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/Power_Point'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/Power_Point'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# Power_Point
#
# +-------------------------------+-------------------------------+----------------------+----------------------+-----------------+---------------+----------------+--------------------+----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |    Nombre Archivo Anterior    |     Nombre Archivo Actual     |    Ruta Anterior     |      Nueva Ruta      | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |  Tamaño (Megabytes)  | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('TXT\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/TXT'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/TXT'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# TXT
#
# +---------------------------------+---------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |     Nombre Archivo Anterior     |      Nombre Archivo Actual      | Ruta Anterior |  Nueva Ruta  | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |  Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +---------------------------------+---------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+-----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('Word\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/Word'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/Word'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# Word
#
# +----------------------------------+----------------------------------+---------------+---------------+-----------------+---------------+----------------+--------------------+----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |     Nombre Archivo Anterior      |      Nombre Archivo Actual       | Ruta Anterior |  Nueva Ruta   | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |  Tamaño (Megabytes)  | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +----------------------------------+----------------------------------+---------------+---------------+-----------------+---------------+----------------+--------------------+----------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...

# %%
import os
import shutil
import pandas as pd
from tabulate import tabulate
import datetime

print('XML\n')

def obtener_info_archivos_en_carpeta(ruta_carpeta):
    info_archivos = []

    for nombre_archivo in os.listdir(ruta_carpeta):
        ruta_completa = os.path.join(ruta_carpeta, nombre_archivo)

        ruta_anterior = ruta_carpeta

        nueva_ruta = '/content/XML'
        shutil.move(ruta_completa, os.path.join(nueva_ruta, nombre_archivo))

        info = {
            'Nombre Archivo Anterior': nombre_archivo,
            'Nombre Archivo Actual': nombre_archivo,
            'Ruta Anterior': ruta_anterior,
            'Nueva Ruta': nueva_ruta,
            'Tipo de Archivo': nombre_archivo.split('.')[-1],
            'Tamaño (bits)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) * 8,
            'Tamaño (bytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)),
            'Tamaño (Kilobytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / 1024,
            'Tamaño (Megabytes)': os.path.getsize(os.path.join(nueva_ruta, nombre_archivo)) / (1024 ** 2),
            'Vocales': sum(1 for char in nombre_archivo if char.lower() in 'aeiou'),
            'Consonantes': sum(1 for char in nombre_archivo if char.isalpha() and char.lower() not in 'aeiou'),
            'Fecha de Creación': datetime.datetime.fromtimestamp(os.path.getctime(os.path.join(nueva_ruta, nombre_archivo))),
            'Última Fecha de Modificación': datetime.datetime.fromtimestamp(os.path.getmtime(os.path.join(nueva_ruta, nombre_archivo))),
            'Cantidad de Archivos del Mismo Tipo': sum(1 for f in os.listdir(nueva_ruta) if f.endswith(nombre_archivo.split('.')[-1]))
        }

        info_archivos.append(info)

    return info_archivos

ruta_carpeta_trabajo = '/content/XML'

info_archivos = obtener_info_archivos_en_carpeta(ruta_carpeta_trabajo)

df_archivos = pd.DataFrame(info_archivos)

column_order = [
    'Nombre Archivo Anterior', 'Nombre Archivo Actual', 'Ruta Anterior', 'Nueva Ruta',
    'Tipo de Archivo', 'Tamaño (bits)', 'Tamaño (bytes)', 'Tamaño (Kilobytes)', 'Tamaño (Megabytes)',
    'Vocales', 'Consonantes', 'Fecha de Creación', 'Última Fecha de Modificación', 'Cantidad de Archivos del Mismo Tipo'
]
print(tabulate(df_archivos[column_order], headers='keys', tablefmt='pretty', showindex=False))
# Out:
# XML
#
# +------------------------------+------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+------------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# |   Nombre Archivo Anterior    |    Nombre Archivo Actual     | Ruta Anterior |  Nueva Ruta  | Tipo de Archivo | Tamaño (bits) | Tamaño (bytes) | Tamaño (Kilobytes) |   Tamaño (Megabytes)   | Vocales | Consonantes |     Fecha de Creación      | Última Fecha de Modificación | Cantidad de Archivos del Mismo Tipo |
# +------------------------------+------------------------------+---------------+--------------+-----------------+---------------+----------------+--------------------+------------------------+---------+-------------+----------------------------+------------------------------+-------------------------------------+
# ...
